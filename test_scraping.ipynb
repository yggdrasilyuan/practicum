# %%
import matplotlib.pyplot as plt
import yfinance as yf

tickers = ['BABA', 'BIDU', 'GOOGL', 'FB', 'AMZN']

start_date = '2020-01-01'
end_date = '2022-12-31'
data = yf.download(tickers = tickers, start = start_date, end = end_date)
data.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
#
# 1 Failed download:
# - FB: No timezone found, symbol may be delisted
#                      Adj Close                                         \
#                           AMZN        BABA        BIDU  FB      GOOGL
# Date
# 2020-01-02 00:00:00  94.900497  219.770004  138.220001 NaN  68.433998
# 2020-01-03 00:00:00  93.748497  217.000000  133.800003 NaN  68.075996
# 2020-01-06 00:00:00  95.143997  216.639999  135.940002 NaN  69.890503
# 2020-01-07 00:00:00  95.343002  217.630005  136.699997 NaN  69.755501
# 2020-01-08 00:00:00  94.598503  218.000000  137.830002 NaN  70.251999
#
#                          Close                                         ...  \
#                           AMZN        BABA        BIDU  FB      GOOGL  ...
# Date                                                                   ...
# 2020-01-02 00:00:00  94.900497  219.770004  138.220001 NaN  68.433998  ...
# 2020-01-03 00:00:00  93.748497  217.000000  133.800003 NaN  68.075996  ...
# 2020-01-06 00:00:00  95.143997  216.639999  135.940002 NaN  69.890503  ...
# 2020-01-07 00:00:00  95.343002  217.630005  136.699997 NaN  69.755501  ...
# 2020-01-08 00:00:00  94.598503  218.000000  137.830002 NaN  70.251999  ...
#
#                           Open                                         \
#                           AMZN        BABA        BIDU  FB      GOOGL
# Date
# 2020-01-02 00:00:00  93.750000  216.600006  129.490005 NaN  67.420502
# 2020-01-03 00:00:00  93.224998  216.350006  134.580002 NaN  67.400002
# 2020-01-06 00:00:00  93.000000  214.889999  132.779999 NaN  67.581497
# 2020-01-07 00:00:00  95.224998  217.639999  138.190002 NaN  70.023003
# 2020-01-08 00:00:00  94.902000  216.600006  136.740005 NaN  69.740997
#
#                        Volume
#                          AMZN      BABA     BIDU  FB     GOOGL
# Date
# 2020-01-02 00:00:00  80580000  15873500  8001400 NaN  27278000
# 2020-01-03 00:00:00  75288000   8604500  5184800 NaN  23408000
# 2020-01-06 00:00:00  81236000  11885500  3930700 NaN  46768000
# 2020-01-07 00:00:00  80898000   9388000  4535800 NaN  34330000
# 2020-01-08 00:00:00  70160000  11959100  3818900 NaN  35314000
#
# [5 rows x 30 columns]

# %%
df = data['Adj Close']
# df.head()
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
type(df)
data.to_csv("D:\\stock_data\\sample.csv",sep=",",header=True)
