# %%
import pandas as pd
import dask.dataframe as dd                            
import matplotlib.pyplot as plt
import numpy as np

data=dd.read_csv("D:\\stock_data\\GMRF_Pricing.csv",sep=",")
# type(data)
# data["PRICEDATE"]
data
# Out:
# Dask DataFrame Structure:
#                 TRADINGITEMID TICKERSYMBOL PRICEDATE     OPEN    CLOSE VOLUME ADJ_OPEN ADJ_CLOSE ADJ_VOLUME CURRENCYNAME TRADINGSTATUS EXCHANGENAME IMPORTANCELEVEL
# npartitions=280
#                         int64       object    object  float64  float64  int64  float64   float64    float64       object        object       object           int64
#                           ...          ...       ...      ...      ...    ...      ...       ...        ...          ...           ...          ...             ...
# ...                       ...          ...       ...      ...      ...    ...      ...       ...        ...          ...           ...          ...             ...
#                           ...          ...       ...      ...      ...    ...      ...       ...        ...          ...           ...          ...             ...
# ...

# %%
data["date"] = dd.to_datetime(data["PRICEDATE"])

# %%
import pandas as pd
import dask.dataframe as dd                            
import matplotlib.pyplot as plt
import numpy as np

use_cols=["TRADINGITEMID","PRICEDATE","ADJ_CLOSE","CURRENCYNAME"]
parse_dates=["PRICEDATE"]
pd_data=dd.read_csv("D:\\stock_data\\GMRF_Pricing.csv",sep=",",usecols=use_cols,parse_dates=parse_dates)
pd_data
# pd_data.info()
# Out:
# Dask DataFrame Structure:
#                 TRADINGITEMID            PRICEDATE ADJ_CLOSE CURRENCYNAME
# npartitions=280
#                         int64  datetime64[ns, UTC]   float64       object
#                           ...                  ...       ...          ...
# ...                       ...                  ...       ...          ...
#                           ...                  ...       ...          ...
#                           ...                  ...       ...          ...
# Dask Name: read-csv, 280 tasks

# %%
data_t=pd_data.set_index(pd_data["PRICEDATE"],drop=False)
data_g=data_t.groupby(data_t.index.to_period(freq='m')).tail(1)
data_g
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27284\106710494.py in <module>
#       1 data_t=pd_data.set_index(pd_data["PRICEDATE"],drop=False)
# ----> 2 data_g=data_t.groupby(data_t.index.to_period(freq='m')).tail(1)
#       3 data_g
#
# c:\Users\yggdrasilyuan\AppData\Local\conda\conda\envs\practicum\lib\site-packages\dask\dataframe\core.py in __getattr__(self, key)
#    3920         elif key in self._monotonic_attributes:
#    3921             return getattr(self, key)
# -> 3922         raise AttributeError("'Index' object has no attribute %r" % key)
#    3923
#    3924     def __dir__(self):
#
# AttributeError: 'Index' object has no attribute 'to_period'
