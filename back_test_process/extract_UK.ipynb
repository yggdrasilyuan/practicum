# %%
import pandas as pd
import numpy as np

parse_data=["FILING_DATE"]
data=pd.read_csv("D://stock_data/all_mapping_0304.csv",parse_dates=parse_data,encoding="ISO-8859-1")
# data

# %%
CA_data=data[data["COUNTRY"]=="United Kingdom"]
CA_data.reset_index(inplace=True)
CA_data
# CA_data_out=CA_data["FILING_DATE","word_count"]CA_data_q
# Out:
#         index       ID  DOCUMENT_ID DOCUMENT_TYPE FILING_DATE  \
# 0        3580  3174689      3063879            AR  2014-12-31
# 1        3581  2967075       747172            AR  2015-12-31
# 2       12584  3742176     40736166            AR  2006-06-08
# 3       12585  2684472    121474330            AR  2019-08-22
# 4       12586  2689181    121473998            AR  2019-08-22
# ...       ...      ...          ...           ...         ...
# 25802  417740  3175672     24662629            AR  2014-12-31
# 25803  417741  2967101     13580072            AR  2015-12-31
# 25804  417742  2967101     13580072            AR  2015-12-31
# 25805  417743  2838799     73659153            AR  2017-12-31
# 25806  417744  2902410    135253604            AR  2018-12-31
#
#         DETAIL_JSONcompany_name  avg_sent   FILINGID            FILINGDATE  \
# 0           Avon Products, Inc.      0.03    3063879                   NaN
# 1           Avon Products, Inc.      0.16     747172                   NaN
# 2      Doncasters Group Limited      0.16   40736166  2006-06-08T20:00:00Z
# 3      Doncasters Group Limited      0.11  121474330  2019-08-22T05:15:00Z
# 4      Doncasters Group Limited      0.36  121473998  2019-08-22T05:15:00Z
# ...                         ...       ...        ...                   ...
# 25802     Nostrum Oil & Gas PLC     -0.35   24662629                   NaN
# 25803     Nostrum Oil & Gas PLC      0.05   13580072                   NaN
# 25804     Nostrum Oil & Gas PLC      0.09   13580072                   NaN
# 25805     Nostrum Oil & Gas PLC     -0.05   73659153                   NaN
# 25806     Nostrum Oil & Gas PLC      0.04  135253604                   NaN
#
#                  PERIODDATE  ...            SECTOR  \
# 0      2014-12-31T00:00:00Z  ...  Consumer Staples
# 1      2015-12-31T00:00:00Z  ...  Consumer Staples
# 2      2005-12-31T00:00:00Z  ...       Industrials
# 3      2015-12-31T00:00:00Z  ...       Industrials
# 4      2016-12-31T00:00:00Z  ...       Industrials
# ...                     ...  ...               ...
# 25802  2014-12-31T00:00:00Z  ...            Energy
# 25803  2015-12-31T00:00:00Z  ...            Energy
# 25804  2015-12-31T00:00:00Z  ...            Energy
# 25805  2017-12-31T00:00:00Z  ...            Energy
# 25806  2018-12-31T00:00:00Z  ...            Energy
#
#            SIMPLEINDUSTRYDESCRIPTION  REGION         COUNTRY sum_sent  \
# 0                  Personal Products  Europe  United Kingdom     3.12
# 1                  Personal Products  Europe  United Kingdom     9.73
# 2              Aerospace and Defense  Europe  United Kingdom     6.43
# 3              Aerospace and Defense  Europe  United Kingdom     2.33
# 4              Aerospace and Defense  Europe  United Kingdom     4.68
# ...                              ...     ...             ...      ...
# 25802  Oil, Gas and Consumable Fuels  Europe  United Kingdom   -22.23
# 25803  Oil, Gas and Consumable Fuels  Europe  United Kingdom     4.15
# 25804  Oil, Gas and Consumable Fuels  Europe  United Kingdom     6.02
# 25805  Oil, Gas and Consumable Fuels  Europe  United Kingdom    -4.94
# 25806  Oil, Gas and Consumable Fuels  Europe  United Kingdom     5.33
#
#       hit_count  positive_hits negative_hits section_count word_count
# 0          5865           3106          2759           212    61789.0
# 1          6231           3306          2925           228    68177.0
# 2           846            587           259            96     8881.0
# 3          1636            877           759            41    20951.0
# 4          1925           1104           821            76    24168.0
# ...         ...            ...           ...           ...        ...
# 25802      6953           3965          2988           193    85097.0
# 25803      5937           3542          2395           392    74196.0
# 25804      5706           3460          2246           379    70605.0
# 25805     10306           5529          4777           298   119532.0
# 25806      7555           4284          3271           393    89100.0
#
# [25807 rows x 27 columns]

# %%
parse_data1=["PRICEDATE"]
stock_data=pd.read_csv("D://stock_data/uk_stock.csv",parse_dates=parse_data1)
stock_data
# Out:
#           index  TRADINGITEMID TICKERSYMBOL  PRICEDATE      OPEN     CLOSE  \
# 0         43629        2592032          AVP 2006-01-31  28.20000  28.32000
# 1         43630        2592032          AVP 2006-02-28  29.06000  28.85000
# 2         43631        2592032          AVP 2006-03-31  30.86000  31.17000
# 3         43632        2592032          AVP 2006-04-28  31.92000  32.61000
# 4         43633        2592032          AVP 2006-05-31  31.56000  31.70000
# ...         ...            ...          ...        ...       ...       ...
# 338289  6199678     1823875816          NOG 2022-10-31   0.02020   0.02500
# 338290  6199679     1823875816          NOG 2022-11-30   0.02500   0.02245
# 338291  6199680     1823875816          NOG 2022-12-30       NaN   0.02750
# 338292  6199681     1823875816          NOG 2023-01-31       NaN   0.02900
# 338293  6199682     1823875816          NOG 2023-02-27   0.19675   0.19250
#
#             VOLUME  ADJ_OPEN  ADJ_CLOSE  ADJ_VOLUME   CURRENCYNAME  \
# 0        7266500.0  28.20000   28.32000   7266500.0      US Dollar
# 1        2342400.0  29.06000   28.85000   2342400.0      US Dollar
# 2        3022100.0  30.86000   31.17000   3022100.0      US Dollar
# 3       12846700.0  31.92000   32.61000  12846700.0      US Dollar
# 4        1738700.0  31.56000   31.70000   1738700.0      US Dollar
# ...            ...       ...        ...         ...            ...
# 338289       268.0   0.02020    0.02500       268.0  British Pound
# 338290      3946.0   0.02500    0.02245      3946.0  British Pound
# 338291         NaN       NaN    0.02750         NaN  British Pound
# 338292         NaN       NaN    0.02900         NaN  British Pound
# 338293      9667.0   0.19675    0.19250      9667.0  British Pound
#
#        TRADINGSTATUS             EXCHANGENAME  IMPORTANCELEVEL  Unnamed: 13  \
# 0             Merged  New York Stock Exchange              1.0          289
# 1             Merged  New York Stock Exchange              1.0          289
# 2             Merged  New York Stock Exchange              1.0          289
# 3             Merged  New York Stock Exchange              1.0          289
# 4             Merged  New York Stock Exchange              1.0          289
# ...              ...                      ...              ...          ...
# 338289        Active    London Stock Exchange             59.0        51451
# 338290        Active    London Stock Exchange             59.0        51451
# 338291        Active    London Stock Exchange             59.0        51451
# 338292        Active    London Stock Exchange             59.0        51451
# 338293        Active    London Stock Exchange             59.0        51451
#
#        TICKERSYMBOL_right  REGION         COUNTRY
# 0                     AVP  Europe  United Kingdom
# 1                     AVP  Europe  United Kingdom
# 2                     AVP  Europe  United Kingdom
# 3                     AVP  Europe  United Kingdom
# 4                     AVP  Europe  United Kingdom
# ...                   ...     ...             ...
# 338289                NOG  Europe  United Kingdom
# 338290                NOG  Europe  United Kingdom
# 338291                NOG  Europe  United Kingdom
# 338292                NOG  Europe  United Kingdom
# 338293                NOG  Europe  United Kingdom
#
# [338294 rows x 18 columns]

# %%
time=pd.date_range(start='2006-01-01', freq='M', periods=206)
# str(time[3])
time
CA_data_out=CA_data[["FILING_DATE","word_count","TRADINGITEMID"]]
CA_data_out.set_index(CA_data["FILING_DATE"],drop=False,inplace=True)
gp=CA_data_out.groupby(CA_data_out.index.to_period(freq="m"))
gp.size().sort_values().tail(20)
# len(time)
# Out:
# FILING_DATE
# 2011-12     357
# 2020-04     381
# 2012-12     386
# 2016-12     392
# 2014-12     394
# 2019-12     402
# 2018-03     404
# 2013-12     406
# 2019-06     406
# 2018-04     410
# 2015-12     410
# 2020-06     444
# 2018-06     455
# 2018-12     536
# 2021-03     544
# 2017-12     569
# 2019-04     578
# 2019-03     628
# 2022-03     956
# 2021-05    1336
# Freq: M, dtype: int64

# %%
# time2=pd.date_range(start=str(time[2]), freq='M', periods=2)
# time2
# type(pd.to_datetime(time[0])[0])

open_day=time[0]
close_day=time[1]

# 获取每月中word_count 值最高和最低的五个股票
def get_up_low(open_day,close_day):
    con1=CA_data_out['FILING_DATE']>=open_day
    con2=CA_data_out['FILING_DATE']<close_day
    CA_data_q=CA_data_out[con1&con2]

    # CA_data_q=CA_data_out[CA_data_out["FILING_DATE"]>=pd.to_datetime(time[0])& CA_data_out["FILING_DATE"]<=pd.to_datetime(time[2])]
    CA_data_q=CA_data_q.sort_values(['word_count'])
    # CA_data_q["TRADINGITEMID"].duplicated()
    CA_data_q=CA_data_q["TRADINGITEMID"].drop_duplicates()
    if(len(CA_data_q)>=10):
        stock_id_u=CA_data_q.head(5)
        up=stock_id_u.to_list()
        stock_id_d=CA_data_q.tail(5)
        down=stock_id_d.to_list()
        return up,down
    else:
        list_nan=[np.nan]
        return list_nan,list_nan
# down

# %%
import math
# con1=CA_data_out['FILING_DATE']>=open_day
# con2=CA_data_out['FILING_DATE']<close_day
# CA_data_q=CA_data_out[con1&con2]

# # CA_data_q=CA_data_out[CA_data_out["FILING_DATE"]>=pd.to_datetime(time[0])& CA_data_out["FILING_DATE"]<=pd.to_datetime(time[2])]
# CA_data_q=CA_data_q.sort_values(['word_count'])
# # CA_data_q["TRADINGITEMID"].duplicated()
# # CA_data_q=CA_data_q["TRADINGITEMID"].drop_duplicates()
# # stock_id_u=CA_data_q.head(5)
# # stock_id_u
# CA_data_q

# up=stock_id_u.to_list()
# stock_id_d=CA_data_q.tail(5)
# down=stock_id_d.to_list()
# part1=stock_data['PRICEDATE']>open_day
# part2=stock_data['PRICEDATE']<=close_day
# part3=stock_data["TRADINGITEMID"]==up[2]
# stockdata=stock_data[part3&part2&part1]
# if(stockdata.empty==False):
#     re=(stockdata["ADJ_CLOSE"]-stockdata["ADJ_OPEN"])/stockdata["ADJ_OPEN"]
#     val=re.tail().values[0]
# else:
#     val=np.nan


# val
# # stockdata.empty
# math.isnan(val)

# %%
# CA_data_q


#通过两组高低投资组合中的股票提取当月的股票价格并得到回报，大改
def get_re(open_day,close_day,stock_id):
    part1=stock_data['PRICEDATE']>open_day
    part2=stock_data['PRICEDATE']<=close_day
    part3=stock_data["TRADINGITEMID"]==stock_id
    stockdata=stock_data[part3&part2&part1]
    if(stockdata.empty==False):
        re=np.log(stockdata["ADJ_CLOSE"]/stockdata["ADJ_OPEN"])
        val=re.tail().values[0]
    else:
        val=np.nan
    return val

# %%
up_v=[]
down_v=[]

#第一个循环将跑完整个股票日期从2006到2023
for i in range(len(time)-1):
    open_day=time[i]
    close_day=time[i+1]
    # print(open_day)
    #获取两组股票
    up,down=get_up_low(open_day,close_day)
    # print(up)
    temp=0
    #在低值组通过累加取均值得到portfolio回报并填入新表
    for i in down:
        flag=0
        if(math.isnan(get_re(open_day,close_day,i))==False):
            temp+=get_re(open_day,close_day,i)
        else:
            flag+=1

    if((len(down)-flag)!=0):
        down_t=temp/(len(down)-flag)
        down_v.append(down_t)
    else:
        down_v.append(0)

    for i in up:
        if(math.isnan(get_re(open_day,close_day,i))==False):
            temp+=get_re(open_day,close_day,i)
        else:
            flag+=1

    if((len(down)-flag)!=0):
        up_t=temp/(len(down)-flag)
        up_v.append(up_t)
    else:
        up_v.append(0)

len(up_v)
# Out:
# 205

# %%
#将两组数据写入新表
portfolio=pd.DataFrame({'date':pd.date_range(start='2006-01-01', freq='M', periods=205)})
portfolio["up_p"]=up_v
portfolio["down_p"]=down_v
portfolio['up-down']=portfolio["up_p"]-portfolio["down_p"]
portfolio
# Out:
#           date      up_p    down_p   up-down
# 0   2006-01-31 -0.000000  0.000000 -0.000000
# 1   2006-02-28 -0.020008 -0.010844 -0.009164
# 2   2006-03-31  0.000158  0.000569 -0.000411
# 3   2006-04-30 -0.000000  0.000000 -0.000000
# 4   2006-05-31  0.009573  0.004006  0.005567
# ..         ...       ...       ...       ...
# 200 2022-09-30  0.021457  0.005746  0.015711
# 201 2022-10-31 -0.001491  0.002017 -0.003508
# 202 2022-11-30 -0.009941 -0.007952 -0.001988
# 203 2022-12-31  0.003501  0.001841  0.001660
# 204 2023-01-31 -0.000000  0.000000 -0.000000
#
# [205 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(1)
plt.plot(portfolio["date"],portfolio["up_p"].cumsum(),'r',label='up_return')
plt.plot(portfolio["date"],portfolio["down_p"].cumsum(),'b',label='down_return')
plt.plot(portfolio["date"],portfolio["up-down"].cumsum(),'y',label='up-down')
plt.xlabel("date")
plt.ylabel("return")
plt.legend() 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# portfolio.to_csv("D://stock_data//ca_backtest_portfolio.csv",header=True,index=0)
